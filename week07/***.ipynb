# %% [markdown]
# <a href="https://colab.research.google.com/github/rutijanasandra-svg/ores5160-2025/blob/main/week07/***.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1b0f553-8d9b-431d-b97f-1cd9cab6d84f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1b0f553-8d9b-431d-b97f-1cd9cab6d84f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  'edited_us_air_quality_one_week_2022_06_23 (1) (1).csv',
#  'edited_us_air_quality_one_week_2022_06_23 (1).csv',
#  'sample_data']

# %%
import pandas as pd
df = pd.read_csv('/content/edited_us_air_quality_one_week_2022_06_23 (1) (1).csv')

# %%
pd.set_option('display.max_rows', 1000)
df.head(1000)
# Out:
#                  location                                 city country  \
# 0    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 1    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 2    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 3    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 4    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 5    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 6    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 7    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 8    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 9    MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 10   MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# 11   MILWAUKEE COLLEGE AV        Milwaukee-Waukesha-West Allis      US
# ...

# %%
df.head(5)
# Out:
#                location                           city country pollutant  \
# 0  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 1  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 2  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 3  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 4  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
#
#    value   unit source_name  latitude  longitude  averaged_over_in_hours  \
# 0   0.33  µg/m³      AirNow         1   42.93257               -87.93434
# 1   1.68  µg/m³      AirNow         1   42.93257               -87.93434
# 2   0.63  µg/m³      AirNow         1   42.93257               -87.93434
# 3   1.86  µg/m³      AirNow         1   42.93257               -87.93434
# 4   0.33  µg/m³      AirNow         1   42.93257               -87.93434
#
#        location_geom        date      time
# 0  POINT(42.93257 1)  2022-05-26  05:00:00
# ...

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170579 entries, 0 to 170578
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   location                170524 non-null  object
#  1   city                    170251 non-null  object
#  2   country                 170579 non-null  object
#  3   pollutant               170579 non-null  object
#  4   value                   170579 non-null  float64
#  5   unit                    170579 non-null  object
#  6   source_name             170579 non-null  object
#  7   latitude                170579 non-null  int64
#  8   longitude               170579 non-null  float64
#  9   averaged_over_in_hours  170579 non-null  float64
#  10  location_geom           170579 non-null  object
#  11  date                    170579 non-null  object
#  12  time                    170579 non-null  object
# dtypes: float64(3), int64(1), object(9)
# ...

# %%
df.isnull().sum()
# Out:
# location                   55
# city                      328
# country                     0
# pollutant                   0
# value                       0
# unit                        0
# source_name                 0
# latitude                    0
# longitude                   0
# averaged_over_in_hours      0
# location_geom               0
# date                        0
# time                        0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# location                  0
# city                      0
# country                   0
# pollutant                 0
# value                     0
# unit                      0
# source_name               0
# latitude                  0
# longitude                 0
# averaged_over_in_hours    0
# location_geom             0
# date                      0
# time                      0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['location', 'city', 'country', 'pollutant', 'value', 'unit',
#        'source_name', 'latitude', 'longitude', 'averaged_over_in_hours',
#        'location_geom', 'date', 'time'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

df[df['pollutant'] == 'pm25']['value'].hist(bins=30)
plt.title('Distribution of PM2.5 Values')
plt.xlabel('PM2.5')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

df[df['pollutant'] == 'pm25']['value'].plot(kind='box')
plt.title('Boxplot of PM2.5 Values')
plt.ylabel('PM2.5')
plt.show()
