# %% [markdown]
# <a href="https://colab.research.google.com/github/rutijanasandra-svg/ores5160-2025/blob/main/week10Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def count_vowels(s):
    vowels = "aeiouAEIOU"
    count = 0

# %%
def count_vowels(s):
    return sum(1 for char in s if char.lower() in "aeiou")

assert count_vowels("hello") == 2
assert count_vowels("HELLO") == 2
assert count_vowels("xyz") == 0

print("All tests passed!")
# Out:
# All tests passed!

# %%
import doctest
doctest.run_docstring_examples(count_vowels, globals(), verbose=True)
# Out:
# Finding tests in NoName

# %%
def count_vowels(s):
    """
    Returns the number of vowels in a string.

    >>> count_vowels("hello")
    2
    >>> count_vowels("HELLO")
    2
    >>> count_vowels("xyz")
    0
    """
    return sum(1 for char in s if char.lower() in "aeiou")

# %%
def bmi(weight_kg, height_m):
    """
    Calculates Body Mass Index (BMI).

    >>> bmi(70, 1.75)
    22.86
    >>> bmi(60, 1.6)
    23.44
    >>> bmi(80, 1.8)
    24.69
    """
    return round(weight_kg / (height_m ** 2), 2)

# %%
print(bmi(70, 1.75))
print(bmi(60, 1.6))
print(bmi(80, 1.8))
# Out:
# 22.86
# 23.44
# 24.69

# %%
import doctest
doctest.run_docstring_examples(bmi, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     bmi(70, 1.75)
# Expecting:
#     22.86
# ok
# Trying:
#     bmi(60, 1.6)
# Expecting:
#     23.44
# ok
# Trying:
#     bmi(80, 1.8)
# Expecting:
#     24.69
# ok

# %%
def filter_short(words, max_len):
    return [word for word in words if len(word) <= max_len]

# %%
assert filter_short(['hi', 'hello', 'no', 'yes'], 2) == ['hi', 'no']
assert filter_short(['apple', 'banana', 'pear'], 4) == ['pear']
